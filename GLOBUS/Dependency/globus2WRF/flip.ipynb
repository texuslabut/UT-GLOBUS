# %%
import numpy as np
import pandas as pd

# %%
data = np.loadtxt('MeanBuildingHeight_average_1kmx1km.txt')[:]

# %%
data[1]
# Out:
# 7.391904079

# %%
new = np.reshape(data, (-1, 151))

# %%
import matplotlib.pyplot as plt

# %%
new = np.transpose(new)
plt.imshow(new)

# %%
data2 = np.flipud(new)

# %%
data2[0,0]
# Out:
# 10.60892443

# %%
plt.imshow(data2)

# %%
data2 = data2.flatten('F')

# %%
import pandas as pd

# %%
df = pd.DataFrame(data2)

# %%
df.to_csv('test.csv')
